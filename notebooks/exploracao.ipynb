# %% [markdown]
# Pipeline dados CPU

# %%
import pandas as pd
from sqlalchemy import create_engine

dados = pd.read_csv(r"..\data_raw\CT-Log 2025-06-28 00-48-52.csv", encoding="latin1", skiprows=7)

# %%
# Escolhendo colunas
dados = dados.loc[:, ~dados.columns.str.startswith("Unnamed")]
dados = dados.drop(columns=["Core 0", "Core 1", "Core 2", "Core 3", "Core 4", "Core 5"])

# %%
dados.columns
# Out:
# Index(['Time', 'Core 0 Temp. (°)', 'Core 1 Temp. (°)', 'Core 2 Temp. (°)',
#        'Core 3 Temp. (°)', 'Core 4 Temp. (°)', 'Core 5 Temp. (°)',
#        'Low temp. (°)', 'High temp. (°)', 'Core load (%)', 'Core speed (MHz)',
#        'Low temp. (°).1', 'High temp. (°).1', 'Core load (%).1',
#        'Core speed (MHz).1', 'Low temp. (°).2', 'High temp. (°).2',
#        'Core load (%).2', 'Core speed (MHz).2', 'Low temp. (°).3',
#        'High temp. (°).3', 'Core load (%).3', 'Core speed (MHz).3',
#        'Low temp. (°).4', 'High temp. (°).4', 'Core load (%).4',
#        'Core speed (MHz).4', 'Low temp. (°).5', 'High temp. (°).5',
#        'Core load (%).5', 'Core speed (MHz).5', 'CPU 0 Power'],
#       dtype='object')

# %%
dados["Time"] = pd.to_datetime(dados["Time"], format="%H:%M:%S %m/%d/%y", errors="coerce")

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                290 non-null    datetime64[ns]
#  1   Core 0 Temp. (°)    290 non-null    int64
#  2   Core 1 Temp. (°)    290 non-null    int64
#  3   Core 2 Temp. (°)    290 non-null    int64
#  4   Core 3 Temp. (°)    290 non-null    int64
#  5   Core 4 Temp. (°)    290 non-null    int64
#  6   Core 5 Temp. (°)    290 non-null    int64
#  7   Low temp. (°)       290 non-null    int64
#  8   High temp. (°)      290 non-null    int64
#  9   Core load (%)       290 non-null    int64
#  10  Core speed (MHz)    290 non-null    float64
#  11  Low temp. (°).1     290 non-null    int64
#  12  High temp. (°).1    290 non-null    int64
#  13  Core load (%).1     290 non-null    int64
#  14  Core speed (MHz).1  290 non-null    float64
# ...

# %%
dados = dados[['Time',
                'Core 0 Temp. (°)',
                'Low temp. (°)',
                'High temp. (°)',
                'Core load (%)',
                'Core speed (MHz)',
                'Core 1 Temp. (°)', 
                'Low temp. (°).1',
                'High temp. (°).1',
                'Core load (%).1',
                'Core speed (MHz).1',
                'Core 2 Temp. (°)',
                'Low temp. (°).2',
                'High temp. (°).2',
                'Core load (%).2',
                'Core speed (MHz).2',
                'Core 3 Temp. (°)',
                'Low temp. (°).3',
                'High temp. (°).3',
                'Core load (%).3',
                'Core speed (MHz).3',
                'Core 4 Temp. (°)',
                'Low temp. (°).4',
                'High temp. (°).4',
                'Core load (%).4',
                'Core speed (MHz).4',
                'Core 5 Temp. (°)',
                'Low temp. (°).5',
                'High temp. (°).5',
                'Core load (%).5',
                'Core speed (MHz).5',
                'CPU 0 Power']]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                290 non-null    datetime64[ns]
#  1   Core 0 Temp. (°)    290 non-null    int64
#  2   Low temp. (°)       290 non-null    int64
#  3   High temp. (°)      290 non-null    int64
#  4   Core load (%)       290 non-null    int64
#  5   Core speed (MHz)    290 non-null    float64
#  6   Core 1 Temp. (°)    290 non-null    int64
#  7   Low temp. (°).1     290 non-null    int64
#  8   High temp. (°).1    290 non-null    int64
#  9   Core load (%).1     290 non-null    int64
#  10  Core speed (MHz).1  290 non-null    float64
#  11  Core 2 Temp. (°)    290 non-null    int64
#  12  Low temp. (°).2     290 non-null    int64
#  13  High temp. (°).2    290 non-null    int64
#  14  Core load (%).2     290 non-null    int64
# ...

# %%
dados.to_csv(r"..\data_processed\CT-Log_2025-06-28_00-48-52.csv", index=False)

# %%
dados_processados = pd.read_csv("C:/Users/pedro/OneDrive/Área de Trabalho/Registros CPU/data_processed/CT-Log 2025-06-28 11-14-18.csv")

# %%
dados_processados
# Out:
#                      Time  Core 0 Temp. (°)  Low temp. (°)  High temp. (°)  \
# 0     2025-06-28 11:14:28                71             67              72
# 1     2025-06-28 11:14:38                70             67              73
# 2     2025-06-28 11:14:48                74             67              74
# 3     2025-06-28 11:14:58                75             67              78
# 4     2025-06-28 11:15:08                66             64              78
# ...                   ...               ...            ...             ...
# 5368  2025-06-29 02:09:07                77             57              92
# 5369  2025-06-29 02:09:17                79             57              92
# 5370  2025-06-29 02:09:27                79             57              92
# 5371  2025-06-29 02:09:37                81             57              92
# 5372  2025-06-29 02:09:47                78             57              92
#
# ...
